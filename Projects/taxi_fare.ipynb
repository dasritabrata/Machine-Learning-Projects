# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import (
    StandardScaler,
    OrdinalEncoder,
    LabelEncoder,
    OneHotEncoder
)
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

from sklearn.linear_model import LinearRegression, Ridge,Lasso,LogisticRegression
from sklearn.neighbors import KNeighborsRegressor

from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor,AdaBoostRegressor
from sklearn.ensemble import ExtraTreesRegressor

from sklearn.model_selection import train_test_split, GridSearchCV,cross_validate, cross_val_predict
# Scikit-learn: Metrics
from sklearn.metrics import r2_score, mean_squared_error

# %%
path="/Users/ritabratadas/Desktop/STUDY FOLDERS/Machine Learning/PROJECTS/DATASETS/taxi_fare_train.csv"
df=pd.read_csv(path)

# %%
df
# Out:
#       VendorID   tpep_pickup_datetime   tpep_dropoff_datetime  \
# 0            0   2023-06-28 17:31:46    2023-06-28 18:22:12
# 1            0   2023-06-29 19:15:55    2023-06-29 19:07:31
# 2            1   2023-06-30 18:28:50    2023-06-30 18:01:19
# 3            1   2023-06-30 22:57:37    2023-06-30 22:55:34
# 4            1   2023-06-28 18:39:16    2023-06-28 17:31:29
# ...        ...                    ...                     ...
# 9995         1   2023-06-28 16:38:27    2023-06-28 17:02:20
# 9996         1   2023-06-30 15:59:37    2023-06-30 17:43:59
# 9997         1   2023-06-29 09:26:14    2023-06-29 11:22:26
# 9998         1   2023-06-30 17:43:41    2023-06-30 17:46:22
# 9999         1   2023-06-29 21:54:57    2023-06-29 22:25:39
#
#        passenger_count   trip_distance   RatecodeID   store_and_fwd_flag  \
# 0                  1.0            1.50          1.0   N
# 1                  1.0            3.80          1.0   N
# ...

# %%
# remove all white space globally 


df = df.replace(r'^\s*$', np.nan, regex=True)

# %%
df.columns
# Out:
# Index(['VendorID', ' tpep_pickup_datetime', ' tpep_dropoff_datetime',
#        ' passenger_count', ' trip_distance', ' RatecodeID',
#        ' store_and_fwd_flag', ' PULocationID', ' DOLocationID',
#        ' payment_type', ' extra', ' tip_amount         ', ' tolls_amount',
#        ' improvement_surcharge', ' total_amount', ' congestion_surcharge',
#        ' Airport_fee'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()

# %%
X=df.drop(columns="total_amount",axis=1)

# %%
X
# Out:
#       VendorID   tpep_pickup_datetime   tpep_dropoff_datetime  \
# 0            0   2023-06-28 17:31:46    2023-06-28 18:22:12
# 1            0   2023-06-29 19:15:55    2023-06-29 19:07:31
# 2            1   2023-06-30 18:28:50    2023-06-30 18:01:19
# 3            1   2023-06-30 22:57:37    2023-06-30 22:55:34
# 4            1   2023-06-28 18:39:16    2023-06-28 17:31:29
# ...        ...                    ...                     ...
# 9995         1   2023-06-28 16:38:27    2023-06-28 17:02:20
# 9996         1   2023-06-30 15:59:37    2023-06-30 17:43:59
# 9997         1   2023-06-29 09:26:14    2023-06-29 11:22:26
# 9998         1   2023-06-30 17:43:41    2023-06-30 17:46:22
# 9999         1   2023-06-29 21:54:57    2023-06-29 22:25:39
#
#        passenger_count  trip_distance   RatecodeID   store_and_fwd_flag  \
# 0                  1.0           1.50          1.0   N
# 1                  1.0           3.80          1.0   N
# ...

# %%
i=(X["store_and_fwd_flag"].unique()[1])

# %%
X["store_and_fwd_flag"] = X["store_and_fwd_flag"].replace(i, X["store_and_fwd_flag"].unique()[0])

# %%
X["store_and_fwd_flag"].value_counts()
# Out:
# store_and_fwd_flag
# N                     9931
# Y                       69
# Name: count, dtype: int64

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               10000 non-null  int64
#  1   tpep_pickup_datetime   10000 non-null  object
#  2   tpep_dropoff_datetime  10000 non-null  object
#  3   passenger_count        9634 non-null   object
#  4   trip_distance          10000 non-null  float64
#  5   RatecodeID             9634 non-null   object
#  6   store_and_fwd_flag     10000 non-null  object
#  7   PULocationID           10000 non-null  int64
#  8   DOLocationID           10000 non-null  int64
#  9   payment_type           10000 non-null  object
#  10  extra                  10000 non-null  float64
#  11  tip_amount             10000 non-null  float64
#  12  tolls_amount           10000 non-null  float64
#  13  improvement_surcharge  10000 non-null  float64
# ...

# %%
y=df["total_amount"]

# %%
y.head()
# Out:
# 0    24.80
# 1    31.55
# 2    24.84
# 3    13.45
# 4    29.88
# Name: total_amount, dtype: float64

# %%
# different types of columns
num_cols = [
    "trip_distance",
    "extra",
    "tip_amount",
    "tolls_amount",
    "improvement_surcharge"
]

num_like_cols = [
    "passenger_count",
    "RatecodeID",
    "congestion_surcharge",
    "Airport_fee"
]


date_cols = [
    "tpep_pickup_datetime",
    "tpep_dropoff_datetime"
]

# %%
le=LabelEncoder()
X["store_and_fwd_flag"]=le.fit_transform(X["store_and_fwd_flag"])
X["payment_type"]=le.fit_transform(X["payment_type"])

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               10000 non-null  int64
#  1   tpep_pickup_datetime   10000 non-null  object
#  2   tpep_dropoff_datetime  10000 non-null  object
#  3   passenger_count        9634 non-null   object
#  4   trip_distance          10000 non-null  float64
#  5   RatecodeID             9634 non-null   object
#  6   store_and_fwd_flag     10000 non-null  int64
#  7   PULocationID           10000 non-null  int64
#  8   DOLocationID           10000 non-null  int64
#  9   payment_type           10000 non-null  int64
#  10  extra                  10000 non-null  float64
#  11  tip_amount             10000 non-null  float64
#  12  tolls_amount           10000 non-null  float64
#  13  improvement_surcharge  10000 non-null  float64
# ...

# %%
from sklearn.base import BaseEstimator, TransformerMixin

# %%
# custom transformer for date and time
class DateFeatureExtractor(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        self.cols_ = X.columns   # store column names
        return self
    
    def transform(self, X):
        X = X.copy()
        
        for col in self.cols_:
            X[col] = pd.to_datetime(X[col])
            X[col + "_hour"] = X[col].dt.hour
            X[col + "_day"] = X[col].dt.day
            X[col + "_weekday"] = X[col].dt.weekday
        
        # drop ONLY original date columns
        return X.drop(columns=self.cols_)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=1)

# %%
num_pipeline=Pipeline([
    ("imputer",SimpleImputer(strategy="median")),
    ("scaler",StandardScaler())
])

date_pipeline = Pipeline([
    ("date_features", DateFeatureExtractor())
])

preprocessor = ColumnTransformer([
    ("num", num_pipeline, num_cols),
    ("num_like", num_pipeline, num_like_cols),
    ("date", date_pipeline, date_cols)
])

# pipeline = Pipeline([
#     ("preprocessing", preprocessor),
#     ("model",RandomForestRegressor())
# ])

# %%
from sklearn.svm import SVR

models = {
    "LinearRegression": LinearRegression(),
    "Ridge": Ridge(),
    "Lasso": Lasso(),
    "RandomForest": RandomForestRegressor(),
    "GradientBoosting": GradientBoostingRegressor(),
    "SVR": SVR(),
    "KNN": KNeighborsRegressor()
}

# %%
from sklearn.pipeline import Pipeline
from sklearn.metrics import root_mean_squared_error

results = {}

for name, model in models.items():
    pipe = Pipeline([
        ("preprocessing", preprocessor),
        ("model", model)
    ])
    
    pipe.fit(X_train, y_train)
    preds = pipe.predict(X_test)
    
    rmse = root_mean_squared_error(y_test, preds)
    r2=r2_score(y_true=y_test,y_pred=preds)
    results[name] = r2

    
    print(f"{name}:  RMSE error = {rmse}    r2_score = {r2}")
    print("="*100)
# Out:
# LinearRegression:  RMSE error = 10.703317276321144    r2_score = 0.8445444240176379
# ...
# Ridge:  RMSE error = 10.702549885550512    r2_score = 0.8445667144710827
# ...
# Lasso:  RMSE error = 10.9762011040908    r2_score = 0.8365166168148939
# ...
# RandomForest:  RMSE error = 8.52283553541113    r2_score = 0.9014315967005143
# ...
# GradientBoosting:  RMSE error = 7.925494594712899    r2_score = 0.9147641583685525
# ...
# SVR:  RMSE error = 20.54873113058339    r2_score = 0.42701991843416787
# ...
# KNN:  RMSE error = 12.944164541341916    r2_score = 0.7726381704254235
# ...

# %%
pipe
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['trip_distance', 'extra',
#                                                    'tip_amount', 'tolls_amount',
#                                                    'improvement_surcharge']),
#                                                  ('num_like',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
# ...

# %%
import matplotlib.pyplot as plt

# results = {"ModelName": rmse, ...}

plt.figure()
bars = plt.bar(names, scores)

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, f"{yval:.2f}",
             ha='center', va='bottom')

plt.xlabel("Models")
plt.ylabel("r2_score")
plt.title("Model Comparison")

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 6
#       3 # results = {"ModelName": rmse, ...}
#       5 plt.figure()
# ----> 6 bars = plt.bar(names, scores)
#       8 for bar in bars:
#       9     yval = bar.get_height()
#
# NameError: name 'names' is not defined

# %% [markdown]
# ## Hyperparameter tuning
